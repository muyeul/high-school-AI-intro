# %%
def stepfunction(X):
  if X <= 0:
    return 0
  elif X > 0:
    return 1

def perceptron(x1, x2):
  w1, w2, wb = 0.5, 0.5, -0.7
  temp = x1 * w1 + x2 * w2 + wb
  return stepfunction(temp)

print(perceptron(0, 1))
print(perceptron(1, 1))
# Out:
# 0
# 1
