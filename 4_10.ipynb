# %% [markdown]
# # [STEP 1] 라이브러리 호출하기

# %%
import tensorflow as tf
import keras
from sklearn import datasets
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# # [STEP 2] 붓꽃 데이터를 학습 데이터와 테스트 데이터로 나누기

# %%
iris = datasets.load_iris( )
X = iris.data
Y = iris.target
Y_oh = OneHotEncoder( ).fit_transform(Y.reshape(-1, 1)).toarray( )
train_x, test_x, train_y, test_y = train_test_split(X, Y_oh, test_size = 0.20)

# %% [markdown]
# # [STEP 3] 붓꽃 분류를 위한 신경망 모델 구현하기

# %%
model = Sequential( )
model.add(Dense(4, input_dim = 4, activation = 'relu'))
model.add(Dense(3, activation = 'softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.fit(train_x, train_y, epochs = 300, batch_size = 10)
# Out:
# Epoch 1/300
# 12/12 [==============================] - 15s 2ms/step - loss: 4.3114 - accuracy: 0.3058
# Epoch 2/300
# 12/12 [==============================] - 0s 2ms/step - loss: 3.3225 - accuracy: 0.4014
# Epoch 3/300
# 12/12 [==============================] - 0s 2ms/step - loss: 3.5776 - accuracy: 0.2983
# Epoch 4/300
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9479 - accuracy: 0.3031
# Epoch 5/300
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9565 - accuracy: 0.3284
# Epoch 6/300
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6746 - accuracy: 0.3058
# Epoch 7/300
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6614 - accuracy: 0.3278
# Epoch 8/300
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7353 - accuracy: 0.2275
# Epoch 9/300
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2702 - accuracy: 0.2898
# Epoch 10/300
# ...

# %% [markdown]
# # [STEP 4] 결과 출력하기

# %%
results = model.evaluate(test_x, test_y)
print('test accuracy: {:4f}'.format(results[1]))
# Out:
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3215 - accuracy: 0.9667
# test accuracy: 0.966667
