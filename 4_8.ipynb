# %% [markdown]
# # [STEP 1] 라이브러리 호출하기

# %%
import numpy as np
#import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# # [STEP 2] 데이터를 배열에 저장하고 W값을 초기화하기

# %%
X = np.array([1,2,3,4,5,6])
Y = np.array([2,4,6,8,10,12])
tf.random.set_seed(0)
W = tf.Variable(tf.random.normal([1], 0, 1))

# %% [markdown]
# # [STEP 3] cost와 W값을 출력하기

# %%
for step in range(3001):
  hypothesis = W * X
  cost = tf.reduce_mean(tf.square(hypothesis - Y))
  alpha = 0.0001
  gradient = tf.reduce_mean(tf.multiply(tf.multiply(W, X)-Y, X))
  descent = W - tf.multiply(alpha, gradient)
  W = descent

  if step % 300 == 0:
    print("{:5} | {:10.4f} | {:10.6f}". format(step, cost.numpy(), 
                                               W.numpy()[0]))
# Out:
#     0 |     3.6257 |   1.511804
#   300 |     1.4584 |   1.690372
#   600 |     0.5867 |   1.803625
#   900 |     0.2360 |   1.875453
#  1200 |     0.0949 |   1.921009
#  1500 |     0.0382 |   1.949901
#  1800 |     0.0154 |   1.968226
#  2100 |     0.0062 |   1.979848
#  2400 |     0.0025 |   1.987219
#  2700 |     0.0010 |   1.991894
#  3000 |     0.0004 |   1.994859
